# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset=pd.read_csv("cluster.csv")
datasett=dataset.iloc[:,[3,4]]

# %%
from sklearn.cluster import SpectralClustering
sc=SpectralClustering(n_clusters=3,assign_labels='discretize',random_state=0).fit(datasett)
y_SC=sc.fit_predict(datasett)
# Out:
# C:\Users\sadiq\anaconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:393: UserWarning: Exited at iteration 727 with accuracies
# [7.04083956e-15 1.07043002e-06 7.92069710e-06 2.32610285e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 517 instead with accuracy
# 1.7271483395864234e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Users\sadiq\anaconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [3.09770611e-15 6.01087484e-07 7.81070305e-07 5.52643557e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# C:\Users\sadiq\anaconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:393: UserWarning: Exited at iteration 727 with accuracies
# [7.04083956e-15 1.07043002e-06 7.92069710e-06 2.32610285e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 517 instead with accuracy
# ...

# %%
import matplotlib.pyplot as plt

# Scatter plot for the clusters
plt.scatter(datasett.iloc[y_SC == 0, 0], datasett.iloc[y_SC == 0, 1], 
            s=50, c='red', label='Cluster 1')
plt.scatter(datasett.iloc[y_SC == 1, 0], datasett.iloc[y_SC == 1, 1], 
            s=50, c='blue', label='Cluster 2')

# Adding title and labels
plt.title('Spectral Clustering Results')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
