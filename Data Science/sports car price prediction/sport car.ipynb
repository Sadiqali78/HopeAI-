# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
dataset=pd.read_csv("Sport car price.csv")
dataset
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021              EV       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021              EV       1888           1696
#
#       0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
dataset.isnull().sum()
# Out:
# Car Make                    0
# Car Model                   0
# Year                        0
# Engine Size (L)            10
# Horsepower                  0
# Torque (lb-ft)              3
# 0-60 MPH Time (seconds)     0
# Price (in USD)              0
# dtype: int64

# %%
dataset['Engine Size (L)']
# Out:
# 0         3
# 1       5.2
# 2       3.9
# 3       5.2
# 4         4
#        ...
# 1002      5
# 1003     EV
# 1004      4
# 1005      6
# 1006     EV
# Name: Engine Size (L), Length: 1007, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 1007 non-null   object
#  1   Car Model                1007 non-null   object
#  2   Year                     1007 non-null   int64
#  3   Engine Size (L)          997 non-null    object
#  4   Horsepower               1007 non-null   object
#  5   Torque (lb-ft)           1004 non-null   object
#  6   0-60 MPH Time (seconds)  1007 non-null   float64
#  7   Price (in USD)           1007 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 63.1+ KB

# %%
null_rows = dataset[dataset['Engine Size (L)'].isnull()]
print(null_rows)
# Out:
#     Car Make       Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 168    Rimac           C_Two  2022             NaN       1914           1696
# 171    Tesla   Model S Plaid  2021             NaN       1020           1050
# 222  Porsche  Taycan Turbo S  2021             NaN        750            774
# 247    Tesla   Model S Plaid  2022             NaN       1020           1050
# 387    Rimac           C_Two  2022             NaN       1888           1696
# 389    Tesla        Roadster  2022             NaN      10000              0
# 686    Rimac           C_Two  2022             NaN       1914           1696
# 697    Lotus           Evija  2022             NaN       1972           1254
# 752  Porsche          Taycan  2022             NaN        469            479
# 916    Tesla        Roadster  2022             NaN     10,000            NaN
#
#      0-60 MPH Time (seconds) Price (in USD)
# 168                     1.90      24,00,000
# ...

# %%
null_rows = dataset[dataset['Torque (lb-ft)'].isnull()]
print(null_rows)
# Out:
#      Car Make      Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 642     Tesla  Model S Plaid  2021              EV       1020            NaN
# 878  Maserati    GranTurismo  2021              EV        550            NaN
# 916     Tesla       Roadster  2022             NaN     10,000            NaN
#
#      0-60 MPH Time (seconds) Price (in USD)
# 642                      1.9       1,39,990
# 878                      2.8       2,00,000
# 916                      1.9       2,00,000

# %%
new_dataset=dataset.dropna()
new_dataset
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021              EV       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021              EV       1888           1696
#
#       0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
new_dataset.isna().sum()
# Out:
# Car Make                   0
# Car Model                  0
# Year                       0
# Engine Size (L)            0
# Horsepower                 0
# Torque (lb-ft)             0
# 0-60 MPH Time (seconds)    0
# Price (in USD)             0
# dtype: int64

# %%
new_dataset
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021              EV       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021              EV       1888           1696
#
#       0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
new_dataset.describe()
# Out:
#               Year  0-60 MPH Time (seconds)
# count   995.000000               995.000000
# mean   2021.195980                 3.528814
# std       2.030646                 0.766891
# min    1965.000000                 1.800000
# 25%    2021.000000                 2.900000
# 50%    2021.000000                 3.500000
# 75%    2022.000000                 4.000000
# max    2023.000000                 6.500000

# %%
new_dataset.duplicated().sum()
# Out:
# 290

# %%
new_dataset.drop_duplicates(inplace = True)
# Out:
# C:\Users\sadiq\AppData\Local\Temp\ipykernel_9636\3011506890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset.drop_duplicates(inplace = True)

# %%
new_dataset.duplicated().sum()
# Out:
# 0

# %%
#new_dataset.tail()

# %%
dataset = pd.get_dummies(new_dataset)
dataset.sum()
# Out:
# Year                       1424911.00
# 0-60 MPH Time (seconds)       2523.27
# Car Make_Acura                   6.00
# Car Make_Alfa Romeo             15.00
# Car Make_Alpine                  1.00
#                               ...
# Price (in USD)_96,950            3.00
# Price (in USD)_98,395            1.00
# Price (in USD)_99,000            1.00
# Price (in USD)_99,800            1.00
# Price (in USD)_99,990            1.00
# Length: 834, dtype: float64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 705 entries, 0 to 1006
# Columns: 834 entries, Year to Price (in USD)_99,990
# dtypes: bool(832), float64(1), int64(1)
# memory usage: 589.3 KB

# %%
unique_count = len(new_dataset['Car Model'].unique())  
print(unique_count)
# Out:
# 176

# %%
unique_count = len(new_dataset['Car Make'].unique()) 
print(unique_count)
# Out:
# 38

# %%
unique_count = len(new_dataset['Engine Size (L)'].unique()) 
print(unique_count)
# Out:
# 39

# %%
unique_count = len(new_dataset['Horsepower'].unique()) 
print(unique_count)
# Out:
# 120

# %%
import pandas as pd
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
le = LabelEncoder()

# Apply Label Encoding to 'Car Model' column
new_dataset['Car Model'] = le.fit_transform(new_dataset['Car Model'])
new_dataset['Car Make'] = le.fit_transform(new_dataset['Car Make'])

# Print the updated dataset
print(new_dataset)
# Out:
#       Car Make  Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0           28         18  2022               3        379            331
# 1           16         98  2021             5.2        630            443
# 2           11          5  2022             3.9        661            561
# 3            5        130  2022             5.2        562            406
# 4           21         15  2021               4        710            568
# ...        ...        ...   ...             ...        ...            ...
# 999         24          1  2021             3.7        332            270
# 1002        15         99  2022               5       1280           1106
# 1003        18         76  2021              EV       1972           1254
# 1005        25         95  2021               6        764            738
# 1006        29        122  2021              EV       1888           1696
#
#       0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
new_dataset
# Out:
#       Car Make  Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0           28         18  2022               3        379            331
# 1           16         98  2021             5.2        630            443
# 2           11          5  2022             3.9        661            561
# 3            5        130  2022             5.2        562            406
# 4           21         15  2021               4        710            568
# ...        ...        ...   ...             ...        ...            ...
# 999         24          1  2021             3.7        332            270
# 1002        15         99  2022               5       1280           1106
# 1003        18         76  2021              EV       1972           1254
# 1005        25         95  2021               6        764            738
# 1006        29        122  2021              EV       1888           1696
#
#       0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 705 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 705 non-null    int32
#  1   Car Model                705 non-null    int32
#  2   Year                     705 non-null    int64
#  3   Engine Size (L)          705 non-null    object
#  4   Horsepower               705 non-null    object
#  5   Torque (lb-ft)           705 non-null    object
#  6   0-60 MPH Time (seconds)  705 non-null    float64
#  7   Price (in USD)           705 non-null    object
# dtypes: float64(1), int32(2), int64(1), object(4)
# memory usage: 44.1+ KB

# %%
new_dataset
# Out:
#       Car Make  Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0           28         18  2022               3        379            331
# 1           16         98  2021             5.2        630            443
# 2           11          5  2022             3.9        661            561
# 3            5        130  2022             5.2        562            406
# 4           21         15  2021               4        710            568
# ...        ...        ...   ...             ...        ...            ...
# 999         24          1  2021             3.7        332            270
# 1002        15         99  2022               5       1280           1106
# 1003        18         76  2021              EV       1972           1254
# 1005        25         95  2021               6        764            738
# 1006        29        122  2021              EV       1888           1696
#
#       0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
import numpy as np

# Assign 'EV' for 'Engine Size (L)' equal to 'EV', else assign 'Fuel'
new_dataset['Vehicle Type'] = np.where(new_dataset['Engine Size (L)'] == 'EV', 'EV', 'Fuel')

# Assign 'Hybrid' for 'Engine Size (L)' equal to 'Hybrid', else retain the existing value
new_dataset['Vehicle Type'] = np.where(new_dataset['Engine Size (L)'] == 'Hybrid', 'Hybrid', new_dataset['Vehicle Type'])

new_dataset['Engine Size (L)'] = new_dataset['Engine Size (L)'].replace('EV', 0)
new_dataset['Engine Size (L)'] = new_dataset['Engine Size (L)'].replace('Hybrid', 00)

# Check the result
new_dataset['Vehicle Type'].value_counts()
# Out:
# Vehicle Type
# Fuel      670
# EV         33
# Hybrid      2
# Name: count, dtype: int64

# %%
new_dataset.to_csv("pre.csv")

# %%
new_dataset['Vehicle Type'].value_counts()
# Out:
# Vehicle Type
# Fuel      670
# EV         33
# Hybrid      2
# Name: count, dtype: int64

# %%
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 705 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 705 non-null    int32
#  1   Car Model                705 non-null    int32
#  2   Year                     705 non-null    int64
#  3   Engine Size (L)          705 non-null    object
#  4   Horsepower               705 non-null    object
#  5   Torque (lb-ft)           705 non-null    object
#  6   0-60 MPH Time (seconds)  705 non-null    float64
#  7   Price (in USD)           705 non-null    object
#  8   Vehicle Type             705 non-null    object
# dtypes: float64(1), int32(2), int64(1), object(5)
# memory usage: 49.6+ KB
